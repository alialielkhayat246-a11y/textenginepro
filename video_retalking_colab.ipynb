# %% [markdown]
# <a href="https://colab.research.google.com/github/alialielkhayat246-a11y/textenginepro/blob/main/video_retalking_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/
# !git clone https://github.com/camenduru/video-retalking

# !apt -y install -qq aria2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/video-retalking/resolve/main/30_net_gen.pth -d /content/video-retalking/checkpoints -o 30_net_gen.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/video-retalking/resolve/main/BFM.zip -d /content/video-retalking/checkpoints -o BFM.zip
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/video-retalking/resolve/main/DNet.pt -d /content/video-retalking/checkpoints -o DNet.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/video-retalking/resolve/main/ENet.pth -d /content/video-retalking/checkpoints -o ENet.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/video-retalking/resolve/main/GFPGANv1.3.pth -d /content/video-retalking/checkpoints -o GFPGANv1.3.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/video-retalking/resolve/main/GPEN-BFR-512.pth -d /content/video-retalking/checkpoints -o GPEN-BFR-512.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/video-retalking/resolve/main/LNet.pth -d /content/video-retalking/checkpoints -o LNet.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/video-retalking/resolve/main/ParseNet-latest.pth -d /content/video-retalking/checkpoints -o ParseNet-latest.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/video-retalking/resolve/main/RetinaFace-R50.pth -d /content/video-retalking/checkpoints -o RetinaFace-R50.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/video-retalking/resolve/main/expression.mat -d /content/video-retalking/checkpoints -o expression.mat
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/video-retalking/resolve/main/face3d_pretrain_epoch_20.pth -d /content/video-retalking/checkpoints -o face3d_pretrain_epoch_20.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/video-retalking/resolve/main/shape_predictor_68_face_landmarks.dat -d /content/video-retalking/checkpoints -o shape_predictor_68_face_landmarks.dat
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/facexlib/resolve/main/detection_Resnet50_Final.pth -d /usr/local/lib/python3.10/dist-packages/facexlib/weights -o detection_Resnet50_Final.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/facexlib/resolve/main/s3fd-619a316812.pth -d /root/.cache/torch/hub/checkpoints -o s3fd-619a316812.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/facexlib/resolve/main/2DFAN4-cd938726ad.zip -d /root/.cache/torch/hub/checkpoints -o 2DFAN4-cd938726ad.zip
# !unzip -d /content/video-retalking/checkpoints/BFM /content/video-retalking/checkpoints/BFM.zip

# !pip install -q basicsr==1.4.2 face-alignment==1.3.4 facexlib==0.2.5 librosa==0.9.2 ninja==1.11.1.1 einops==0.7.0 kornia==0.7.0 -U
# Out:
# /content
# fatal: destination path 'video-retalking' already exists and is not an empty directory.
# aria2 is already the newest version (1.36.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 481f7a|OK  |       0B/s|/content/video-retalking/checkpoints/30_net_gen.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 93610c|OK  |       0B/s|/content/video-retalking/checkpoints/BFM.zip
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3e392d|OK  |       0B/s|/content/video-retalking/checkpoints/DNet.pt
#
# Status Legend:
# (OK):download completed.
#
# ...

# %%
# %cd /content/video-retalking

# !python inference.py \
  --face "/content/video-retalking/examples/face/1.mp4" \
  --audio "/content/video-retalking/examples/audio/1.wav" \
  --outfile '/content/output_high_qual.mp4'

# %%
# !pip install numpy==1.26.4

# %%
# !pip install numpy==1.26.4

# %%
# !python inference.py --face $video_name --audio $audio_name --outfile result.mp4

# %%
import os
os.system(f"python inference.py --face '{video_name}' --audio '{audio_name}' --outfile result.mp4")

# %%
# !ls /content/video-retalking/*.mp4 /content/video-retalking/*.wav /content/video-retalking/*.mp3 /content/video-retalking/*.MP4 /content/video-retalking/*.WAV

# %%
# %cd /content/video-retalking

from google.colab import files

print("Upload your VIDEO file:")
video = files.upload()
video_name = list(video.keys())[0]

print("Upload your AUDIO file:")
audio = files.upload()
audio_name = list(audio.keys())[0]

import os
os.system(f"python inference.py --face '{video_name}' --audio '{audio_name}' --outfile result.mp4")

# Download the result
files.download("result.mp4")

# %%
# %cd /content/video-retalking
# !ls *.mp4 *.wav *.mp3 *.MP4 *.WAV *.MP3 2>/dev/null

# %%
# !python inference.py --face "{video_name}" --audio "{audio_name}" --outfile result.mp4

# %%
# %cd /content/video-retalking

from google.colab import files

print("Upload your VIDEO file:")
video = files.upload()
video_name = list(video.keys())[0]

print("Upload your AUDIO file:")
audio = files.upload()
audio_name = list(audio.keys())[0]

import os
os.system(f"python inference.py --face '{video_name}' --audio '{audio_name}' --outfile result.mp4")

# Download the result
files.download("result.mp4")

# %%
# %cd /content/video-retalking
# !ls *.mp4 *.wav *.mp3 *.MP4 *.WAV *.MP3 2>/dev/null

# %%
# !python inference.py --face "{video_name}" --audio "{audio_name}" --outfile result.mp4

# %%
# !pip install torchvision==0.18.1 basicsr==1.4.2

# %%
# Step 1: Fix dependencies
# !pip install numpy==1.26.4 basicsr==1.4.2 torchvision==0.18.1 torch==2.3.1

# Step 2: Go to project folder
# %cd /content/video-retalking

# Step 3: Upload files
from google.colab import files

print("=== Upload your VIDEO file ===")
video = files.upload()
video_name = list(video.keys())[0]

print("=== Upload your AUDIO file ===")
audio = files.upload()
audio_name = list(audio.keys())[0]

# Step 4: Run lip-sync
import os
os.system(f"python inference.py --face '{video_name}' --audio '{audio_name}' --outfile result.mp4")

# Step 5: Download result
if os.path.exists("result.mp4"):
    files.download("result.mp4")
    print("Done! Check your downloads.")
else:
    print("Something went wrong - result.mp4 was not created. Check errors above.")

# %%
# Step 1: Fix dependencies
# !pip install numpy==1.26.4 basicsr==1.4.2 torchvision==0.18.1 torch==2.3.1

# Step 2: Go to project folder
# %cd /content/video-retalking

# Step 3: Upload files
from google.colab import files

print("=== Upload your VIDEO file ===")
video = files.upload()
video_name = list(video.keys())[0]

print("=== Upload your AUDIO file ===")
audio = files.upload()
audio_name = list(audio.keys())[0]

# Step 4: Run lip-sync
import os
os.system(f"python inference.py --face '{video_name}' --audio '{audio_name}' --outfile result.mp4")

# Step 5: Download result
if os.path.exists("result.mp4"):
    files.download("result.mp4")
    print("Done! Check your downloads.")
else:
    print("Something went wrong - result.mp4 was not created. Check errors above.")

# %%
# %cd /content/video-retalking
# !python inference.py --face "{video_name}" --audio "{audio_name}" --outfile result.mp4 2>&1

# %%
# Fix the broken import by patching the file directly
# !sed -i 's/from torchvision.transforms.functional_tensor import rgb_to_grayscale/from torchvision.transforms.functional import rgb_to_grayscale/' /usr/local/lib/python3.12/dist-packages/basicsr/data/degradations.py

# Verify the fix
# !grep "rgb_to_grayscale" /usr/local/lib/python3.12/dist-packages/basicsr/data/degradations.py

# %%
# %cd /content/video-retalking
from google.colab import files

print("=== Upload your VIDEO ===")
video = files.upload()
video_name = list(video.keys())[0]

print("=== Upload your AUDIO ===")
audio = files.upload()
audio_name = list(audio.keys())[0]

import os
os.system(f"python inference.py --face '{video_name}' --audio '{audio_name}' --outfile result.mp4")

if os.path.exists("result.mp4"):
    files.download("result.mp4")
    print("Done!")
else:
    print("Failed - check errors above")

# %%
# !cd /content/video-retalking && python inference.py --face '{video_name}' --audio '{audio_name}' --outfile result.mp4

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")

# %%
# !pip install face_alignment dlib einops kornia==0.5.1 facexlib librosa

# Re-apply the fix
# !sed -i 's/from torchvision.transforms.functional_tensor import rgb_to_grayscale/from torchvision.transforms.functional import rgb_to_grayscale/' /usr/local/lib/python3.12/dist-packages/basicsr/data/degradations.py

# %cd /content/video-retalking

from google.colab import files
import os

print("=== Upload your VIDEO ===")
video = files.upload()
video_name = list(video.keys())[0]

print("=== Upload your AUDIO ===")
audio = files.upload()
audio_name = list(audio.keys())[0]

# !python inference.py --face "{video_name}" --audio "{audio_name}" --outfile result.mp4

if os.path.exists("result.mp4"):
    files.download("result.mp4")
    print("Done! Check your downloads.")
else:
    print("Failed - check errors above")

# %%
# !pip install face_alignment dlib einops kornia==0.5.1 facexlib librosa

# Re-apply the fix
# !sed -i 's/from torchvision.transforms.functional_tensor import rgb_to_grayscale/from torchvision.transforms.functional import rgb_to_grayscale/' /usr/local/lib/python3.12/dist-packages/basicsr/data/degradations.py

# %cd /content/video-retalking

from google.colab import files
import os

print("=== Upload your VIDEO ===")
video = files.upload()
video_name = list(video.keys())[0]

print("=== Upload your AUDIO ===")
audio = files.upload()
audio_name = list(audio.keys())[0]

# !python inference.py --face "{video_name}" --audio "{audio_name}" --outfile result.mp4

if os.path.exists("result.mp4"):
    files.download("result.mp4")
    print("Done! Check your downloads.")
else:
    print("Failed - check errors above")
# Out:
# ...
# /content/video-retalking
# === Upload your VIDEO ===
#      <input type="file" id="files-863389d4-ca08-48c0-a0ac-30b4576c44aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-863389d4-ca08-48c0-a0ac-30b4576c44aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# Fix the numpy array issue
# !sed -i "s/trans_params = np.array(\[w0, h0, s, t\[0\], t\[1\]\])/trans_params = np.array([w0, h0, float(s), float(t[0]), float(t[1])])/" /content/video-retalking/third_part/face3d/util/preprocess.py

# Run inference
# %cd /content/video-retalking
# !python inference.py --face "{video_name}" --audio "{audio_name}" --outfile result.mp4

import os
from google.colab import files
if os.path.exists("result.mp4"):
    files.download("result.mp4")
    print("Done!")
else:
    print("Failed - check errors above")
# Out:
# /content/video-retalking
# Traceback (most recent call last):
#   File "/content/video-retalking/inference.py", line 14, in <module>
#     from third_part.face3d.extract_kp_videos import KeypointExtractor
#   File "/content/video-retalking/third_part/face3d/extract_kp_videos.py", line 6, in <module>
#     import face_alignment
#   File "/usr/local/lib/python3.12/dist-packages/face_alignment/__init__.py", line 7, in <module>
#     from .api import FaceAlignment, LandmarksType, NetworkSize
#   File "/usr/local/lib/python3.12/dist-packages/face_alignment/api.py", line 4, in <module>
#     from skimage import io
#   File "<frozen importlib._bootstrap>", line 1412, in _handle_fromlist
#   File "/usr/local/lib/python3.12/dist-packages/lazy_loader/__init__.py", line 75, in __getattr__
#     return importlib.import_module(f"{package_name}.{name}")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/importlib/__init__.py", line 90, in import_module
# ...
